# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./EDA_census.csv')

# %%
df.shape
# Out:
# (3132, 15)

# %%
df.head(10)
# Out:
#    state_code  dist_code area_name population age_group  total_persons  \
# 0           0          0     INDIA      Total  All ages     1210854977
# 1           0          0     INDIA      Total       0-6      164515253
# 2           0          0     INDIA      Total         7       24826640
# 3           0          0     INDIA      Total         8       26968373
# 4           0          0     INDIA      Total         9       23424638
# 5           0          0     INDIA      Total        10       30552107
# 6           0          0     INDIA      Total        11       24740946
# 7           0          0     INDIA      Total        12       27877307
# 8           0          0     INDIA      Total        13       24280683
# 9           0          0     INDIA      Total        14       25258169
#
#    total_males  total_females  illiterate_persons  illiterate_males  \
# 0    623270258      587584719           447216165         188506636
# ...

# %%
df=df.iloc[:,0:-1]

# %%
df.isnull().sum()
# Out:
# state_code            0
# dist_code             0
# area_name             0
# population            0
# age_group             0
# total_persons         0
# total_males           0
# total_females         0
# illiterate_persons    0
# illiterate_males      0
# illiterate_females    0
# literate_persons      0
# literate_males        0
# literate_females      0
# dtype: int64

# %%
q1 = df[(df.age_group == '20-24') & (df.population == 'Total') & (df.area_name == 'INDIA')]

# %%
q1
# Out:
#     state_code  dist_code area_name population age_group  total_persons  \
# 15           0          0     INDIA      Total     20-24      111424222
#
#     total_males  total_females  illiterate_persons  illiterate_males  \
# 15     57584693       53839529            18679492           6467026
#
#     illiterate_females  literate_persons  literate_males  literate_females
# 15            12212466          92744730        51117667          41627063

# %%
q1.total_females/q1.illiterate_females
# Out:
# 15    22.683085
# dtype: float64

# %%
df.age_group.value_counts()
# Out:
# 70-74             108
# 17                108
# 50-54             108
# 13                108
# 15                108
# 60-64             108
# 9                 108
# 12                108
# 7                 108
# 19                108
# 14                108
# 55-59             108
# All ages          108
# 65-69             108
# 18                108
# 8                 108
# 45-49             108
# 30-34             108
# 40-44             108
# Age not stated    108
# 20-24             108
# 75-79             108
# 80+               108
# 10                108
# 11                108
# 16                108
# 25-29             108
# 35-39             108
# 0-6               108
# Name: age_group, dtype: int64

# %%
q2 = df[(df.population == 'Total') & (df.area_name == 'INDIA')]

# %%
q2['literate_avg'] = q2.literate_persons/q2.total_persons*100
# Out:
# <ipython-input-65-2442bf74d1da>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   q2['literate_avg'] = q2.literate_persons/q2.total_persons*100

# %%
q2[['age_group','literate_avg']]
# Out:
#          age_group  literate_avg
# 0         All ages     63.066084
# 1              0-6      0.000000
# 2                7     72.818658
# 3                8     84.680522
# 4                9     89.362038
# 5               10     88.693071
# 6               11     91.962826
# 7               12     91.421234
# 8               13     92.543554
# 9               14     91.682750
# 10              15     89.961344
# 11              16     89.783437
# 12              17     90.392562
# 13              18     86.665872
# 14              19     87.637647
# 15           20-24     83.235699
# 16           25-29     77.681141
# 17           30-34     72.538435
# 18           35-39     67.274016
# 19           40-44     62.993414
# 20           45-49     59.758607
# 21           50-54     57.565672
# 22           55-59     54.830491
# 23           60-64     46.926523
# 24           65-69     43.943993
# 25           70-74     39.774485
# 26           75-79     41.931327
# ...

# %%
plt.figure(figsize=(200,200))
plt.plot(q2.age_group, q2.literate_avg)
# plt.xlabel(q2.age_group)
# plt.ylabel(q2.literate_avg)
plt.show()

# %%
# ?plt

# %% [markdown]
# ### Q3

# %%
q3 = df[(df.age_group == 'All ages') & (df.population == 'Total') & (df.area_name.isin(['State - MADHYA PRADESH','State - KERALA','State - GOA','State - RAJASTHAN']))]

# %%
q3['literate_femal_avg'] = q3.literate_females/q3.total_females*100
# Out:
# <ipython-input-90-8a6caf4f83b1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   q3['literate_femal_avg'] = q3.literate_females/q3.total_females*100

# %%
q3
# Out:
#       state_code  dist_code               area_name population age_group  \
# 696            8          0       State - RAJASTHAN      Total  All ages
# 2001          23          0  State - MADHYA PRADESH      Total  All ages
# 2610          30          0             State - GOA      Total  All ages
# 2784          32          0          State - KERALA      Total  All ages
#
#       total_persons  total_males  total_females  illiterate_persons  \
# 696        68548437     35550997       32997440            30273155
# 2001       72626809     37612306       35014503            29775640
# 2610        1458545       739140         719405              293058
# 2784       33406061     16027412       17378649             5270237
#
#       illiterate_males  illiterate_females  literate_persons  literate_males  \
# 696           11862585            18410570          38275282        23688412
# 2001          12437978            17337662          42851169        25174328
# ...

# %%
df.area_name.value_counts()
# Out:
# State - UTTARAKHAND                  87
# State - SIKKIM                       87
# State - CHANDIGARH                   87
# State - DADRA & NAGAR HAVELI         87
# State - RAJASTHAN                    87
# State - TRIPURA                      87
# State - KERALA                       87
# State - GUJARAT                      87
# State - MANIPUR                      87
# State - MADHYA PRADESH               87
# State - JAMMU & KASHMIR              87
# State - WEST BENGAL                  87
# State - PUNJAB                       87
# State - ODISHA                       87
# State - NCT OF DELHI                 87
# State - LAKSHADWEEP                  87
# State - ANDAMAN & NICOBAR ISLANDS    87
# State - ARUNACHAL PRADESH            87
# State - ANDHRA PRADESH               87
# State - KARNATAKA                    87
# State - NAGALAND                     87
# State - MAHARASHTRA                  87
# State - MEGHALAYA                    87
# ...

# %% [markdown]
# ### Q4

# %%
q4 = df[(df.age_group == 'All ages') & (df.population == 'Total') & (df.area_name.isin(['State - MADHYA PRADESH','State - BIHAR','State - HIMACHAL PRADESH','State - RAJASTHAN']))]

# %%
q4['literate_avg'] = q3.literate_persons/q3.total_persons*100
# Out:
# <ipython-input-94-9780bde35c7a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   q4['literate_avg'] = q3.literate_persons/q3.total_persons*100

# %%
q4
# Out:
#       state_code  dist_code                 area_name population age_group  \
# 174            2          0  State - HIMACHAL PRADESH      Total  All ages
# 696            8          0         State - RAJASTHAN      Total  All ages
# 870           10          0             State - BIHAR      Total  All ages
# 2001          23          0    State - MADHYA PRADESH      Total  All ages
#
#       total_persons  total_males  total_females  illiterate_persons  \
# 174         6864602      3481873        3382729             1824866
# 696        68548437     35550997       32997440            30273155
# 870       104099452     54278157       49821295            51594899
# 2001       72626809     37612306       35014503            29775640
#
#       illiterate_males  illiterate_females  literate_persons  literate_males  \
# 174             729283             1095583           5039736         2752590
# 696           11862585            18410570          38275282        23688412
# ...
